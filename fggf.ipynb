# %% [markdown]
# first_jp

# %% [markdown]
# ## Introduction
# This notebook covers basic concepts of data science including common languages, libraries, tools, and simple arithmetic operations using Python.

# %% [markdown]
# ## Data Science Languages
# Some popular languages used in Data Science include:
# - Python
# - R
# - SQL
# - Julia
# - Scala

# %% [markdown]
# ## Data Science Libraries
# Commonly used data science libraries include:
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - TensorFlow

# %% [markdown]
# ## Data Science Tools
#
# | Tool             | Category          |
# |------------------|-------------------|
# | Jupyter Notebook | IDE/Notebook      |
# | RStudio          | IDE               |
# | Apache Spark     | Big Data Platform |
# | Tableau          | Data Visualization|
# | VS Code          | Text Editor       |

# %% [markdown]
# ## Examples of Arithmetic Expressions
# Below are examples of using Python to perform basic arithmetic operations like addition and multiplication.

# %%
# Multiplication and addition
result = (5 * 4) + 3
result

# %%
# Convert 200 minutes to hours
minutes = 200
hours = minutes / 60
hours

# %% [markdown]
# ## Objectives
# The main objectives of this notebook are:
# - Understand basic concepts of data science
# - Learn about common languages, libraries, and tools
# - Practice basic Python operations
# - Apply markdown formatting in Jupyter Notebooks
